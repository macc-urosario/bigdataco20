# %%
# importar paquetes y darles alias
import pandas as pd
import numpy as np

# %%
# Cargar un archivo como un DataFrame y asignarlo a una variable "data"
data = pd.read_csv("data/red_blood_cells_csv.csv")

# %%
# Mostrar las primeras filas del DF y los nombres de las columnas
data.head()
# Out:
#      etiquetas   Area  Eccentricity  Solidity    Extent  Perimeter  \
# 0  Drepanocits  49102      0.896437  0.989860  0.766452    881.706
# 1  Drepanocits  47888      0.854299  0.991634  0.725851    838.126
# 2  Drepanocits  38226      0.965385  0.979175  0.545229    936.704
# 3  Drepanocits  50034      0.918789  0.985833  0.580003    922.594
# 4  Drepanocits  62347      0.897567  0.987800  0.780811   1009.373
#
#    MajorAxisLength  MinorAxisLength  Circularity  Elongation  ...  \
# 0       376.511849       166.858839     0.793709    0.556830  ...
# 1       342.854428       178.209424     0.856679    0.480218  ...
# 2       435.079969       113.481275     0.547475    0.739171  ...
# 3       402.348475       158.826855     0.738676    0.605251  ...
# 4       427.053434       188.278760     0.768992    0.559121  ...
#
#       Std_Blue  Skewness_G  Skewness_R  Skewness_B  Kurtosis_G  Kurtosis_R  \
# 0  3372.995731    0.535646    0.311529    0.466719    2.398121    2.554637
# ...

# %%
# nombres de las columnas
data.columns
# Out:
# Index(['etiquetas', 'Area', 'Eccentricity', 'Solidity', 'Extent', 'Perimeter',
#        'MajorAxisLength', 'MinorAxisLength', 'Circularity', 'Elongation',
#        'roundnessCH', 'convexity', 'circleVariance', 'ellipVariance',
#        'Mean_Green', 'Mean_Red', 'Mean_Blue', 'Std_Green', 'Std_Red',
#        'Std_Blue', 'Skewness_G', 'Skewness_R', 'Skewness_B', 'Kurtosis_G',
#        'Kurtosis_R', 'Kurtosis_B', 'Entropy_G', 'Entropy_R', 'Entropy_B'],
#       dtype='object')

# %%
# crear una lista (objeto) a partir de los nombres de las columnas
list(data.columns)
# Out:
# ['etiquetas',
#  'Area',
#  'Eccentricity',
#  'Solidity',
#  'Extent',
#  'Perimeter',
#  'MajorAxisLength',
#  'MinorAxisLength',
#  'Circularity',
#  'Elongation',
#  'roundnessCH',
#  'convexity',
#  'circleVariance',
#  'ellipVariance',
#  'Mean_Green',
#  'Mean_Red',
#  'Mean_Blue',
#  'Std_Green',
#  'Std_Red',
#  'Std_Blue',
#  'Skewness_G',
#  'Skewness_R',
#  'Skewness_B',
#  'Kurtosis_G',
#  'Kurtosis_R',
#  'Kurtosis_B',
#  'Entropy_G',
#  'Entropy_R',
#  'Entropy_B']

# %%
# tamaño del DF
data.shape
# Out:
# (1656, 29)

# %%
data["Perimeter"]
# Out:
# 0        881.706
# 1        838.126
# 2        936.704
# 3        922.594
# 4       1009.373
#           ...
# 1651     706.522
# 1652     759.776
# 1653     835.042
# 1654     542.874
# 1655     669.466
# Name: Perimeter, Length: 1656, dtype: float64

# %%
pd.set_option('display.max_rows', None)
data["Perimeter"]
# Out:
# 0        881.706
# 1        838.126
# 2        936.704
# 3        922.594
# 4       1009.373
# 5        778.659
# 6        841.267
# 7        876.688
# 8        965.690
# 9       1009.316
# 10       895.722
# 11      1008.650
# 12       875.868
# 13      1067.592
# 14       879.728
# 15       674.666
# 16      1028.838
# 17       789.680
# 18       918.664
# 19       921.460
# 20       934.226
# 21      1051.114
# 22       806.880
# 23       962.879
# 24       881.448
# 25       987.480
# 26       915.906
# 27       980.458
# 28      1015.774
# 29       913.182
# 30       974.048
# 31       875.836
# 32       837.778
# 33       820.690
# 34       791.854
# 35       914.221
# 36      1026.252
# 37       840.210
# 38      1002.760
# 39       804.172
# 40       826.730
# 41       863.830
# 42       995.832
# 43       804.588
# 44       999.320
# 45       857.578
# 46      1140.283
# 47       914.194
# 48       798.091
# 49       915.274
# 50       800.374
# 51       917.078
# ...

# %%
pd.set_option('display.max_rows', 10)
data["Perimeter"]
# Out:
# 0        881.706
# 1        838.126
# 2        936.704
# 3        922.594
# 4       1009.373
#           ...
# 1651     706.522
# 1652     759.776
# 1653     835.042
# 1654     542.874
# 1655     669.466
# Name: Perimeter, Length: 1656, dtype: float64

# %%
data["Perimeter"].min()
# Out:
# 476.436

# %%
data["Perimeter"].min()
data["Perimeter"].max()
# Out:
# 1159.086

# %%
print(data["Perimeter"].min())
data["Perimeter"].max()
# Out:
# 476.436
# 1159.086

# %%
print("El valor mínimo de Perimeter es: ")
print(data["Perimeter"].min())
print("El valor máximo de Perimeter es: ", data["Perimeter"].max())
# Out:
# El valor mínimo de Perimeter es:
# 476.436
# El valor máximo de Perimeter es:  1159.086

# %%
print("Min: ", data["Perimeter"].min())
print("Max: ", data["Perimeter"].max())
print("Media/promedio: ", data["Perimeter"].mean())
print("Mediana: ", data["Perimeter"].median())
# Out:
# Min:  476.436
# Max:  1159.086
# Media/promedio:  773.8446050724638
# Mediana:  762.2259999999999

# %%
# importar matplotlib.pyplot 
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.plot(data["Perimeter"])

ax.set(xlabel='Observación', 
       ylabel='Perimeter',
       title='Perimeter')
ax.grid()

fig.savefig("perimeter.png")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(data["Perimeter"], 'o')

ax.set(xlabel='Observación', 
       ylabel='Perimeter', 
       title='Perimeter')

plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(data["Perimeter"], 'rx')

ax.set(xlabel='Observación', 
       ylabel='Perimeter',
       title='Perimeter')

plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(data["Perimeter"], color='r', marker = 'x', linestyle = 'None')

ax.set(xlabel='Observación', 
       ylabel='Perimeter',
       title='Perimeter')

plt.show()

# %%
peri1 = data["Perimeter"][0:500] #0:499 - 0:500

print("Min: ", peri1.min())
print("Max: ", peri1.max())
print("Media/promedio: ", peri1.mean())
print("Mediana: ", peri1.median())
# Out:
# Min:  476.436
# Max:  1159.086
# Media/promedio:  900.692336
# Mediana:  907.3530000000001

# %%
data["Perimeter"].describe()
# Out:
# count    1656.000000
# mean      773.844605
# std       137.370084
# min       476.436000
# 25%       656.079500
# 50%       762.226000
# 75%       880.272500
# max      1159.086000
# Name: Perimeter, dtype: float64

# %%
peri1.quantile(0.25)
# Out:
# 840.1057500000001

# %%
print("Cuantil 0.25 (percentil 25): ", peri1.quantile(0.25))
print("Cuantil 0.50 (percentil 50): ", peri1.quantile(0.5))
print("Cuantil 0.75 (percentil 75): ", peri1.quantile(0.75))
# Out:
# Cuantil 0.25 (percentil 25):  840.1057500000001
# Cuantil 0.50 (percentil 50):  907.3530000000001
# Cuantil 0.75 (percentil 75):  963.0502499999999

# %%
plt.hist(x=data["Perimeter"], bins='auto')
# Out:
# (array([  6.,  10.,  81., 124., 193., 167., 124., 131., 123., 137., 114.,
#         116., 117.,  74.,  62.,  44.,  19.,   6.,   8.]),
#  array([ 476.436     ,  512.36494737,  548.29389474,  584.22284211,
#          620.15178947,  656.08073684,  692.00968421,  727.93863158,
#          763.86757895,  799.79652632,  835.72547368,  871.65442105,
#          907.58336842,  943.51231579,  979.44126316, 1015.37021053,
#         1051.29915789, 1087.22810526, 1123.15705263, 1159.086     ]),
#  <BarContainer object of 19 artists>)

# %%
plt.hist(x=data["Perimeter"][1:500], bins='auto')

# %%
plt.hist(x=data["Perimeter"], bins='auto', density=True)
# Out:
# (array([0.00010084, 0.00016807, 0.00136138, 0.00208409, 0.00324379,
#         0.0028068 , 0.00208409, 0.00220174, 0.00206728, 0.00230259,
#         0.00191602, 0.00194963, 0.00196644, 0.00124373, 0.00104205,
#         0.00073952, 0.00031934, 0.00010084, 0.00013446]),
#  array([ 476.436     ,  512.36494737,  548.29389474,  584.22284211,
#          620.15178947,  656.08073684,  692.00968421,  727.93863158,
#          763.86757895,  799.79652632,  835.72547368,  871.65442105,
#          907.58336842,  943.51231579,  979.44126316, 1015.37021053,
#         1051.29915789, 1087.22810526, 1123.15705263, 1159.086     ]),
#  <BarContainer object of 19 artists>)

# %% [markdown]
# **Distribución empírica de Probabilidad**
#
# Entendemos el histograma como una distribución empírica de probabilidad

# %%
# importar plotly express para graficar y boxplot
import plotly.express as px
fig = px.box(data, y="Perimeter")
fig.show()
# Out:
# <div>                            <div id="97ca9ebf-04d9-4a0c-8b6d-09cbcf165de0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97ca9ebf-04d9-4a0c-8b6d-09cbcf165de0")) {                    Plotly.newPlot(                        "97ca9ebf-04d9-4a0c-8b6d-09cbcf165de0",                        [{"alignmentgroup": "True", "hovertemplate": "Perimeter=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x0": " ", "xaxis": "x", "y": [881.706, 838.1260000000001, 936.704, 922.5939999999999, 1009.373, 778.659, 841.2669999999999, 876.688, 965.69, 1009.316, 895.722, 1008.65, 875.868, 1067.5919999999999, 879.7280000000001, 674.666, 1028.83
# ...

# %% [markdown]
# Rango intercuartílico (IQR) = Q3 - Q1 (cuartil 3 - cuartil 1)
#
# Límite inferior: Q1 - 1.5*IQR
#
# Límite superior: Q3 + 1.5*IQR
#
# Outliers/datos atípicos: por fuera de los límites

# %%
tips = px.data.tips()
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig = px.box(tips, y="total_bill")
fig.show()
# Out:
# <div>                            <div id="26b92913-4c1f-45d9-a625-ca6e1132e838" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26b92913-4c1f-45d9-a625-ca6e1132e838")) {                    Plotly.newPlot(                        "26b92913-4c1f-45d9-a625-ca6e1132e838",                        [{"alignmentgroup": "True", "hovertemplate": "total_bill=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x0": " ", "xaxis": "x", "y": [16.99, 10.34, 21.01, 23.68, 24.59, 25.29, 8.77, 26.88, 15.04, 14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29, 16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37, 12.69, 21.7, 1
# ...

# %%
fig = px.box(tips, y="total_bill", x = "smoker")
fig.show()
# Out:
# <div>                            <div id="1427c974-bec3-4148-ab42-905a17e8ed9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1427c974-bec3-4148-ab42-905a17e8ed9b")) {                    Plotly.newPlot(                        "1427c974-bec3-4148-ab42-905a17e8ed9b",                        [{"alignmentgroup": "True", "hovertemplate": "smoker=%{x}<br>total_bill=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "No", "N
# ...

# %%
# gráfico de violín
fig = px.violin(data, y="Perimeter")
fig.show()
# Out:
# <div>                            <div id="26461b1b-ca76-45f8-834d-07b75bdeba25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26461b1b-ca76-45f8-834d-07b75bdeba25")) {                    Plotly.newPlot(                        "26461b1b-ca76-45f8-834d-07b75bdeba25",                        [{"alignmentgroup": "True", "box": {"visible": false}, "hovertemplate": "Perimeter=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "scalegroup": "True", "showlegend": false, "type": "violin", "x0": " ", "xaxis": "x", "y": [881.706, 838.1260000000001, 936.704, 922.5939999999999, 1009.373, 778.659, 841.2669999999999, 876.688, 965.69, 1009.316, 895.722, 1008.65, 875.868, 1067.5919999999999, 8
# ...

# %%
# gráfico de violín con datos y diagrama de caja
fig = px.violin(data, y="Perimeter", box=True, # draw box plot inside the violin
                points='all', # can be 'outliers', or False
               )
fig.show()
# Out:
# <div>                            <div id="1615155e-3fe5-444a-8ed5-c61ebc0b84db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1615155e-3fe5-444a-8ed5-c61ebc0b84db")) {                    Plotly.newPlot(                        "1615155e-3fe5-444a-8ed5-c61ebc0b84db",                        [{"alignmentgroup": "True", "box": {"visible": true}, "hovertemplate": "Perimeter=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "points": "all", "scalegroup": "True", "showlegend": false, "type": "violin", "x0": " ", "xaxis": "x", "y": [881.706, 838.1260000000001, 936.704, 922.5939999999999, 1009.373, 778.659, 841.2669999999999, 876.688, 965.69, 1009.316, 895.722, 1008.65, 875.868, 1067.
# ...

# %%
# importar graph_objects (tomado de https://plotly.com/python/violin/)
import plotly.graph_objects as go


df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/violin_data.csv")

fig = go.Figure()

fig.add_trace(go.Violin(x=df['day'][ df['smoker'] == 'Yes' ],
                        y=df['total_bill'][ df['smoker'] == 'Yes' ],
                        legendgroup='Yes', scalegroup='Yes', name='Yes',
                        side='negative',
                        line_color='blue')
             )
fig.add_trace(go.Violin(x=df['day'][ df['smoker'] == 'No' ],
                        y=df['total_bill'][ df['smoker'] == 'No' ],
                        legendgroup='No', scalegroup='No', name='No',
                        side='positive',
                        line_color='orange')
             )
fig.update_traces(meanline_visible=True)
fig.update_layout(violingap=0, violinmode='overlay')
fig.show()
# Out:
# <div>                            <div id="82d0b53d-9125-4b13-88f4-d12efeeedb24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82d0b53d-9125-4b13-88f4-d12efeeedb24")) {                    Plotly.newPlot(                        "82d0b53d-9125-4b13-88f4-d12efeeedb24",                        [{"legendgroup": "Yes", "line": {"color": "blue"}, "meanline": {"visible": true}, "name": "Yes", "scalegroup": "Yes", "side": "negative", "type": "violin", "x": ["Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Thur", "Thur", "Fri", "Fri", "Fri", "Fri", "Fri", "Fri", "Fri", "Fri", "Fri", "Sat", "Sat", "Sat", "Sat", "Sat", "Sat", "Thur", "Sun", "Sat", "Sat", "Sat", "Sat", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "Sun", "S
# ...

# %%
# mapa de calor
fig = px.imshow([[1, 2, 3, 4],
                 [2, 1, 5, 3],
                 [3, 5, 1, 3],
                 [3, 5, 2, 1]])
fig.show()
# Out:
# <div>                            <div id="63500244-6785-483f-9723-1459d0f02f42" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63500244-6785-483f-9723-1459d0f02f42")) {                    Plotly.newPlot(                        "63500244-6785-483f-9723-1459d0f02f42",                        [{"coloraxis": "coloraxis", "hovertemplate": "x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>", "type": "heatmap", "z": [[1, 2, 3, 4], [2, 1, 5, 3], [3, 5, 1, 3], [3, 5, 2, 1]]}],                        {"coloraxis": {"colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.777777777777777
# ...

# %%
data_simple=[[1, 25, 30, 50, 1], [20, 1, 60, 80, 30], [30, 60, 1, 5, 20]]
fig = px.imshow(data_simple,
                labels=dict(x="Day of Week", y="Time of Day", color="Productivity"),
                x=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'],
                y=['Morning', 'Afternoon', 'Evening']
               )
fig.update_xaxes(side="top")
fig.show()
# Out:
# <div>                            <div id="5c40e6b9-c163-4419-be29-2887bf72af38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c40e6b9-c163-4419-be29-2887bf72af38")) {                    Plotly.newPlot(                        "5c40e6b9-c163-4419-be29-2887bf72af38",                        [{"coloraxis": "coloraxis", "hovertemplate": "Day of Week: %{x}<br>Time of Day: %{y}<br>Productivity: %{z}<extra></extra>", "type": "heatmap", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"], "y": ["Morning", "Afternoon", "Evening"], "z": [[1, 25, 30, 50, 1], [20, 1, 60, 80, 30], [30, 60, 1, 5, 20]]}],                        {"coloraxis": {"colorbar": {"title": {"text": "Productivity"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"
# ...

# %%
fig = px.scatter(x=data["Perimeter"], y=data["Area"])
fig.show()
data.columns
# Out:
# <div>                            <div id="72772775-ad6e-4fb4-b5a7-8c3502203b0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72772775-ad6e-4fb4-b5a7-8c3502203b0a")) {                    Plotly.newPlot(                        "72772775-ad6e-4fb4-b5a7-8c3502203b0a",                        [{"hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [881.706, 838.1260000000001, 936.704, 922.5939999999999, 1009.373, 778.659, 841.2669999999999, 876.688, 965.69, 1009.316, 895.722, 1008.65, 875.868, 1067.5919999999999, 879.7280000000001, 674.666, 1028.838, 789.68, 918.664, 921.46, 934.2260000000001, 1051.114, 806.
# ...

# %%
fig = px.scatter(data, x="Perimeter", y="Area", text="Solidity")
fig.update_traces(textposition='top center')
# Out:
# <div>                            <div id="f36b8fb9-14e4-4299-9445-83dd40d509d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f36b8fb9-14e4-4299-9445-83dd40d509d0")) {                    Plotly.newPlot(                        "f36b8fb9-14e4-4299-9445-83dd40d509d0",                        [{"hovertemplate": "Perimeter=%{x}<br>Area=%{y}<br>Solidity=%{text}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers+text", "name": "", "showlegend": false, "text": [0.989859893, 0.991634225, 0.9791746709999999, 0.98583335, 0.9878004340000001, 0.990655425, 0.94449126, 0.994472997, 0.9870358370000001, 0.9868372940000001, 0.978125191, 0.9873259459999999, 0.994961023, 0.9772812340000001, 0.990908893, 0.985674785
# ...
